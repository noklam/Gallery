# %% [markdown]
# # Testing

# %% [markdown]
# # Notebook

# %%
import pandas as pd
import altair as alt
from matplotlib import pyplot as plt
from pathlib import Path
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATA = Path('data')

# %%
df = pd.read_csv(DATA/'ae_data.csv')
df.head()
# Out:
#                       id    seq topWait                 hospTime  \
# 0   QMH 21/2/2019 9:00am  HK-02     > 2   2019-02-21T09:00:09.29
# 1  AHN 21/2/2019 10:00am  NT-01     > 1  2019-02-21T10:00:01.783
# 2  QMH 21/2/2019 11:00am  HK-02     > 1  2019-02-21T11:00:11.893
# 3  AHN 21/2/2019 12:00pm  NT-01     > 1  2019-02-21T12:00:02.256
# 4  PYN 21/2/2019 12:00pm  HK-01     > 3  2019-02-21T12:00:01.646
#
#                      hospCoord  \
# 0  POINT(114.131259 22.270695)
# 1   POINT(114.17472 22.458575)
# 2  POINT(114.131259 22.270695)
# 3   POINT(114.17472 22.458575)
# 4  POINT(114.235707 22.269419)
#
#                                            hospUrlB5  \
# 0  http://www.ha.org.hk/visitor/ha_visitor_index....
# 1  http://www.ha.org.hk/visitor/ha_visitor_index....
# 2  http://www.ha.org.hk/visitor/ha_visitor_index....
# 3  http://www.ha.org.hk/visitor/ha_visitor_index....
# 4  http://www.ha.org.hk/visitor/ha_visitor_index....
#
# ...

# %%
x=df['hospCoord'].str.extract(r'\((.+)\)')[0].str.split().tolist()
x=pd.DataFrame(x, columns=['Long', 'Lat'])
x.head()
# Out:
#          Long        Lat
# 0  114.131259  22.270695
# 1   114.17472  22.458575
# 2  114.131259  22.270695
# 3   114.17472  22.458575
# 4  114.235707  22.269419

# %%
df = pd.concat([df, x],axis=1)

# %%
df['topWaitTime'] = df['topWait'].copy()
df['topWaitTime']  = df['topWaitTime'].str.replace('> ', '')
df['topWaitTime'][df['topWaitTime']== '< 1'] = 0.5
df['topWaitTime'] = df['topWaitTime'].fillna(0)
df['topWaitTime'] = df['topWaitTime'].astype(float)
# Out:
# /home/nok/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['hospTime'] = pd.to_datetime(df['hospTime'])
df['hospTimeHour'] = df['hospTime'].dt.hour
df['hospTimeWeek'] = df['hospTime'].dt.week
df['hospTimeDay'] = df['hospTime'].dt.day
df['hospTimeYear'] = df['hospTime'].dt.year
df['hospTimeMonth'] = df['hospTime'].dt.month 
df['hospTimeWeekDay'] = df['hospTime'].dt.weekday + 1
df['hospTimeWeekDayName'] = df['hospTime'].dt.weekday_name
# df['hospTimeDate'] = df['hospTime'].dt.date

# %%
df= df[['hospTime','Long', 'Lat','hospTimeWeek','hospTimeWeekDay', 'hospNameEn','hospNameB5','topWaitTime','hospTimeMonth']]

# %%
df.head().T
# Out:
#                                           0  \
# hospTime         2019-02-21 09:00:09.290000
# Long                             114.131259
# Lat                               22.270695
# hospTimeWeek                              8
# hospTimeWeekDay                           4
# hospNameEn              Queen Mary Hospital
# hospNameB5                             瑪麗醫院
# topWaitTime                               2
# hospTimeMonth                             2
#
#                                                      1  \
# hospTime                    2019-02-21 10:00:01.783000
# Long                                         114.17472
# Lat                                          22.458575
# hospTimeWeek                                         8
# hospTimeWeekDay                                      4
# hospNameEn       Alice Ho Miu Ling Nethersole Hospital
# hospNameB5                                 雅麗氏何妙齡那打素醫院
# topWaitTime                                          1
# ...

# %%
df.columns
# Out:
# Index(['hospTime', 'Long', 'Lat', 'hospTimeWeek', 'hospTimeWeekDay',
#        'hospNameEn', 'hospNameB5', 'topWaitTime', 'hospTimeMonth'],
#       dtype='object')

# %%
alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
df_sample = df.query("hospNameEn == 'Queen Mary Hospital'")

# %%
chart1= (alt.Chart(df_sample)
 .mark_rect()
 .encode(y=alt.Y(
        'hospTimeMonth:O',
        sort=alt.EncodingSortField(
            field="hospTimeMonth",  # The field to use for the sort
            op="mean",  # The operation to run on the field prior to sorting
            order="ascending"  # The order to sort in
        ))
         , x='hospTimeDay:O'
        ,color=alt.Color('max(topWaitTime):Q', scale=alt.Scale(scheme='orangered')) )
)
chart1.save('chart1.html')
chart1
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart2=(alt.Chart(df_sample)
 .mark_rect()
 .encode(x=alt.X(
        'hospTimeWeek:O',
        sort=alt.EncodingSortField(
            field="hospTimeWeek",  # The field to use for the sort
            op="mean",  # The operation to run on the field prior to sorting
            order="ascending"  # The order to sort in
        ))
         , y='hospTimeWeekDay:O'
         ,color='max(topWaitTime):Q')
).interactive()
chart2.save('chart2.html')
chart2
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart3=(alt.Chart(df_sample)
 .mark_rect()
 .encode(x='hospTimeWeek:O', y='hospTimeWeekDay:O',color='mean(topWaitTime):Q')
)
chart3.save('chart3.html')
chart3
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart4=(alt.Chart(df)
 .mark_rect()
 .encode(x='hospTimeWeek:O',
         y='hospTimeWeekDay:O' 
        ,color=alt.Color('mean(topWaitTime):Q', scale=alt.Scale(scheme='orangered')))
)
chart4.save('chart4.html')
chart4
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# # Which hospital

# %%
df.columns
# Out:
# Index(['hospTime', 'Long', 'Lat', 'hospTimeWeek', 'hospTimeWeekDay',
#        'hospNameEn', 'hospNameB5', 'topWaitTime', 'hospTimeMonth'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['hospTime', 'Long', 'Lat', 'hospTimeWeek', 'hospTimeWeekDay',
#        'hospNameEn', 'hospNameB5', 'topWaitTime', 'hospTimeMonth'],
#       dtype='object')

# %%
chart5=(alt.Chart(df)
 .mark_rect()
 .encode(x='hospTime:T',
         y='hospNameB5:N' 
        ,color=alt.Color('max(topWaitTime):Q', scale=alt.Scale(scheme='orangered')))
)
chart5.save('chart5.html')
chart5
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
df_sub = df[['hospTime','hospNameEn','hospNameB5','topWaitTime']].copy()

# %%
chart6=(alt.Chart(df_sub)
 .mark_rect()
 .encode(x='yearmonthdate(hospTime):O',
         y='hospNameEn:N',
         color=alt.Color('mean(topWaitTime):Q',
                         scale=alt.Scale(scheme='orangered'),
                         legend=alt.Legend(type='symbol')
                        ),
         tooltip=['mean(topWaitTime):Q','hospNameEn:N','hospNameB5:N'],
         
        )
)

chart6.save('chart6.html')
chart6
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# (alt.Chart(df)
#  .mark_rect()
#  .encode(x='hospTime:T', y='hospTimeHour:Q',color=alt.Color('mean(topWaitTime):Q', scale=alt.Scale(scheme='orangered')))
#  .facet(
#     column='hospNameB5:N'
# ))

# %% [markdown]
# # Map

# %%
# HKG Gov https://www.landsd.gov.hk/mapping/en/news/image/7p_itrf96_hk80_v1.pdf
import altair as alt
from vega_datasets import data

hk_map = 'https://raw.githubusercontent.com/ywng/d3-js-map-hong-kong/master/HKG_adm.json'
map = alt.topo_feature(hk_map, feature='HKG_adm1_1')
background = alt.Chart(map).mark_geoshape(
    fill='lightgray',
    stroke='white'
).properties(
    width=500,
    height=300
).project('mercator')
background.title = 'Hong Kong Hospitals'
background.save('hk_map_background.html')

# %%
# airport positions on background
points = alt.Chart(df).mark_circle().encode(
    longitude='Long:Q',
    latitude='Lat:Q',
    size=alt.value(50),
    color=alt.value('steelblue'),
    tooltip=['hospNameB5', 'hospNameEn']
)

points.save('hk_map_points.html')
demo1 = background|points& background+points
demo1.save('demo1.html')

hk_map_hospital = background + points
hk_map_hospital.save('hk_map_hospital.html')
hk_map_hospital
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# # Bar

# %%
selection = alt.selection_single(fields=['hospNameEn'],name='Random')
color = alt.condition(selection,
#                       alt.value('hospNameB5:N'),
                      alt.value('steelblue'),
                      alt.value('lightgray'))

# %%
bar=(alt.Chart(df)
 .mark_bar()
 .encode(y='mean(topWaitTime):Q',
         x=alt.X('hospNameEn:N',
         sort=alt.EncodingSortField(field='topWaitTime', op='mean', 
                            order='descending')),
         color=color
    
        )
).add_selection(selection)

bar.title ="Mean Waiting Time for Hong Kong's Hospital"
bar.encoding.x.title = 'Hospital'
bar.encoding.y.title = 'Average Waiting Time in Hour(s)'

# %%
color2 = alt.condition(selection,
                      alt.Color('hospNameEn:N'),
#                       alt.value('steelblue'),
                      alt.value('lightgray'))

line1=(alt.Chart(df)
 .mark_line()
 .encode(x=alt.X('hours(hospTime):T'),
         y='mean(topWaitTime):Q',
         color=color2
        
    
        )
)

line1.title ="Waiting Time for Hong Kong's Hospital"
line1.encoding.x.title = 'Hour'
line1.encoding.y.title = 'Average Waiting Time in Hour(s)'

# %%
line2=(alt.Chart(df2)
 .mark_line()
 .encode(x=alt.X('yearmonthdate(hospTime):T'),
         y='mean(topWaitTime):Q'
        
    
        )
).transform_filter(selection)

line2.title ="Average Waiting Time in 1 Day for Hong Kong's Hospital"
line2.encoding.x.title = 'Date'
line2.encoding.y.title = 'Average Waiting Time in Hour(s)'



chart7 = bar|line2&line1
chart7.save('chart7.html')
chart7
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# # Week

# %%
from datetime import timedelta

# %%
start_time = df.hospTime.max() - timedelta(days=30)
end_time = df.hospTime.max()
df_last_30 = df[df['hospTime'] >= start_time].copy()

# %%
start_time = df.hospTime.max() - timedelta(days=7)
end_time = df.hospTime.max()
df_last_week = df[df['hospTime'] >= start_time].copy()

# %%
df_last_30['isVeryBusy'] = df_last_30['topWaitTime'] >=8
df_last_week['isVeryBusy'] = df_last_week['topWaitTime'] >=8

# %%
last_month=(alt.Chart(df_last_30)
 .mark_line()
 .encode(x=alt.X('hours(hospTime):T'),
         y='mean(topWaitTime):Q',
         color=alt.value('red')
        
    
        )
).transform_filter(selection)

# bar.title ="Mean Waiting Time for Hong Kong's Hospital"
# bar.encoding.x.title = 'Hospital'
# bar.encoding.y.title = 'Average Waiting Time in Hour(s)'

final = (hk_map_hospital&bar)|line2&(line1+last_month)
final.save('chart8.html')
# final

# %%
chart9 = bar & line1 + last_month | (line1 & last_month)
chart9.save('chart9.html')
chart9
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
(alt.Chart(df_last_week)
 .mark_line()
 .encode(x=alt.X('hospNameB5'),
         y='BusyDay:Q',
#          color='hospNameB5'
        ).transform_aggregate(BusyDay='sum(isVeryBusy)',
                              groupby=["yearmonthdate(hospTime)","hospNameB5"])
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# # Parallel Coordinate

# %%
import altair as alt
from vega_datasets import data

source = data.iris()
source_transformed = source.reset_index().melt(['species', 'index'])

alt.Chart(source_transformed).mark_line().encode(
    x='variable:N',
    y='value:Q',
    color='species:N',
    detail='index:N',
    opacity=alt.value(0.5)
).properties(width=500)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(df).mark_circle().encode(
    longitude='Long:Q',
    latitude='Lat:Q',
    size=alt.value(30),
    color=alt.value('steelblue')
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(df).mark_circle().encode(
    x='Long:Q',
    y='Lat:Q',
    longitude='Long:Q',
    latitude='Lat:Q',
    size='mean(topWaitTime)',
    color=alt.value('steelblue')
).project('mercator')
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(df).mark_circle().encode(
    longitude='Long:Q',
    latitude='Lat:Q',
    size='topWaitTime',
    color=alt.value('steelblue')
).project('mercator')
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Size('topWaitTime',aggregate='mean',field='topWaitTime',type='quantitative')
# Out:
# Size({
#   aggregate: 'mean',
#   field: 'topWaitTime',
#   shorthand: 'topWaitTime',
#   type: 'quantitative'
# })

# %%
alt.Chart(df).mark_circle().encode(
    longitude='Long:Q',
    latitude='Lat:Q',
    size='meane_acc:Q',
    color=alt.value('steelblue')
).transform_aggregate(
    mean_acc='mean(topWaitTime):Q',
    groupby=['hospNameB5']
 )
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
import altair as alt
from vega_datasets import data

states = alt.topo_feature(data.us_10m.url, 'states')
capitals = data.us_state_capitals.url

# US states background
background = alt.Chart(states).mark_geoshape(
    fill='lightgray',
    stroke='white'
).properties(
    title='US State Capitols',
    width=700,
    height=400
).project('albersUsa')

# Points and text
hover = alt.selection(type='single', on='mouseover', nearest=True,
                      fields=['lat', 'lon'])

base = alt.Chart(capitals).encode(
    longitude='lon:Q',
    latitude='lat:Q'
)

text = base.mark_text(dy=-5, align='right').encode(
    alt.Text('city', type='nominal'),
    opacity=alt.condition(~hover, alt.value(0), alt.value(1))
)

points = base.mark_point().encode(
    color=alt.value('black'),
    size=alt.condition(~hover, alt.value(30), alt.value(100))
).add_selection(hover)

background + points + text
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(df).mark_bar().encode(
x='hospNameB5',
    y='custom:Q').transform_calculate(
      custom='datum.topWaitTime>7'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
